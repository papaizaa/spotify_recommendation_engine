# %% [markdown]
# ## Import all the necessary python packages

# %%
import os
import glob
import requests


from rake_nltk import Rake
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import json

# %% [markdown]
# Save the Spotify API Token. Get your own personal token by following this link: https://developer.spotify.com/console/get-audio-features-several-tracks/?ids= . I would just generate a new token and save it (granted it does expire). You can also do so programatically: https://stackoverflow.com/questions/39887342/how-can-i-get-an-access-token-spotify-api

# %%
spotify_auth = os.getenv("SPOTFIY_API_TOKEN")

# %% [markdown]
# Point to the path where you saved your spotify streaming history.

# %%
spotify_history_path = [os.path.expanduser("~") + '/MySpotifyData/StreamingHistory0.json',
                        os.path.expanduser("~") + '/MySpotifyData/StreamingHistory1.json']

# %%
df = pd.DataFrame()

for file in spotify_history_path:
    data = pd.read_json(file)
    df = temp.append(data, ignore_index = True)

# %%
my_music = df.sample(300)
my_music
# Out:
#                 endTime          artistName                       trackName  \
# 1200   2019-11-12 22:34            Converge                     Hell to Pay
# 20105  2020-09-29 17:34               IDLES         Kill Them With Kindness
# 9065   2020-04-30 18:35             RXYZYXR    Polar Knights (Instrumental)
# 11555  2020-07-01 16:31  The Human Abstract                    Digital Veil
# 10719  2020-06-11 15:19            Kid Cudi  Flight At First Sight/Advanced
# ...                 ...                 ...                             ...
# 3180   2019-12-27 13:30       Freddie Gibbs                      Shitsville
# 16546  2020-06-22 14:36    Protest The Hero                    From the Sky
# 8099   2020-03-26 13:02         Glaswegians                       orwellian
# 6633   2020-03-06 15:47        BROCKHAMPTON                          CANNON
# 19178  2020-09-01 20:41        Elephant Gym                            Head
#
#        msPlayed
# 1200     271773
# 20105    229579
# 9065     294028
# 11555    210360
# 10719    116948
# ...         ...
# 3180       7617
# 16546    374960
# 8099     910042
# 6633      59701
# 19178     56120
#
# [300 rows x 4 columns]

# %%
# query_type: can be 'artist', 'album', 'track'
def make_spotify_search_request(query_type, query):
    params = {'q': query, 'type': query_type, 'limit':1}
    r = requests.get('https://api.spotify.com/v1/search', 
                     headers={"Authorization": "Bearer {}".format(spotify_auth)},
                     params=params)
    if r.status_code == 401:
        raise Exception(r.json())
    return r.json()

# %%
def add_genres_to_artists(df):
    df["genres"] = ""
    for index, row in df.iterrows():
        json = make_spotify_search_request('artist', row['artistName'])
        genre_result = []
        id_result = ""
        if "artists" in json and  "items" in json["artists"]:
            result_list = json["artists"]["items"]
            if len(result_list) > 0:
                genre_result = result_list[0]["genres"]
                id_result = result_list[0]["id"]

        df.at[index, "genres"] = genre_result
        df.at[index, "artistId"] = id_result

add_genres_to_artists(my_music)
my_music
# Out:
#                 endTime          artistName                       trackName  \
# 1200   2019-11-12 22:34            Converge                     Hell to Pay
# 20105  2020-09-29 17:34               IDLES         Kill Them With Kindness
# 9065   2020-04-30 18:35             RXYZYXR    Polar Knights (Instrumental)
# 11555  2020-07-01 16:31  The Human Abstract                    Digital Veil
# 10719  2020-06-11 15:19            Kid Cudi  Flight At First Sight/Advanced
# ...                 ...                 ...                             ...
# 3180   2019-12-27 13:30       Freddie Gibbs                      Shitsville
# 16546  2020-06-22 14:36    Protest The Hero                    From the Sky
# 8099   2020-03-26 13:02         Glaswegians                       orwellian
# 6633   2020-03-06 15:47        BROCKHAMPTON                          CANNON
# 19178  2020-09-01 20:41        Elephant Gym                            Head
#
#        msPlayed                                             genres  \
# 1200     271773  [boston hardcore, chaotic hardcore, mathcore, ...
# 20105    229579  [bristol indie, modern alternative rock, moder...
# 9065     294028     [djent, instrumental progressive metal, thall]
# 11555    210360  [deathcore, djent, melodic metalcore, progress...
# 10719    116948                       [hip hop, ohio hip hop, rap]
# ...         ...                                                ...
# 3180       7617  [alternative hip hop, hip hop, indiana hip hop...
# 16546    374960  [canadian metal, canadian post-hardcore, djent...
# 8099     910042                                                 []
# 6633      59701                           [boy band, hip hop, rap]
# 19178     56120  [instrumental math rock, southeast asian post-...
#
#                      artistId
# 1200   7kHzfxMLtVHHb523s43rY1
# 20105  75mafsNqNE1WSEVxIKuY5C
# 9065   4KScLR4NpZbGiXzj9FSA85
# 11555  2SDGIFzEh9xmE5zDKcMRkj
# 10719  0fA0VVWsXO9YnASrzqfmYu
# ...                       ...
# 3180   0Y4inQK6OespitzD6ijMwb
# 16546  6z3BjfmgvDUIHaJ0UPTtrQ
# 8099   7ezriLBaunXh3OVnmjLG4L
# 6633   1Bl6wpkWCQ4KVgnASpvzzA
# 19178  2rqNUPgkBgbhcRabUQ5C9g
#
# [300 rows x 6 columns]

# %%
# Filter out any artist that doesn't have genres
my_music = my_music[my_music["genres"].apply(len).gt(0)]
my_music
# Out:
#                 endTime          artistName                       trackName  \
# 1200   2019-11-12 22:34            Converge                     Hell to Pay
# 20105  2020-09-29 17:34               IDLES         Kill Them With Kindness
# 9065   2020-04-30 18:35             RXYZYXR    Polar Knights (Instrumental)
# 11555  2020-07-01 16:31  The Human Abstract                    Digital Veil
# 10719  2020-06-11 15:19            Kid Cudi  Flight At First Sight/Advanced
# ...                 ...                 ...                             ...
# 6094   2020-02-28 23:09         Death Grips               I've Seen Footage
# 3180   2019-12-27 13:30       Freddie Gibbs                      Shitsville
# 16546  2020-06-22 14:36    Protest The Hero                    From the Sky
# 6633   2020-03-06 15:47        BROCKHAMPTON                          CANNON
# 19178  2020-09-01 20:41        Elephant Gym                            Head
#
#        msPlayed                                             genres  \
# 1200     271773  [boston hardcore, chaotic hardcore, mathcore, ...
# 20105    229579  [bristol indie, modern alternative rock, moder...
# 9065     294028     [djent, instrumental progressive metal, thall]
# 11555    210360  [deathcore, djent, melodic metalcore, progress...
# 10719    116948                       [hip hop, ohio hip hop, rap]
# ...         ...                                                ...
# 6094     202853  [alternative hip hop, escape room, experimenta...
# 3180       7617  [alternative hip hop, hip hop, indiana hip hop...
# 16546    374960  [canadian metal, canadian post-hardcore, djent...
# 6633      59701                           [boy band, hip hop, rap]
# 19178     56120  [instrumental math rock, southeast asian post-...
#
#                      artistId
# 1200   7kHzfxMLtVHHb523s43rY1
# 20105  75mafsNqNE1WSEVxIKuY5C
# 9065   4KScLR4NpZbGiXzj9FSA85
# 11555  2SDGIFzEh9xmE5zDKcMRkj
# 10719  0fA0VVWsXO9YnASrzqfmYu
# ...                       ...
# 6094   5RADpgYLOuS2ZxDq7ggYYH
# 3180   0Y4inQK6OespitzD6ijMwb
# 16546  6z3BjfmgvDUIHaJ0UPTtrQ
# 6633   1Bl6wpkWCQ4KVgnASpvzzA
# 19178  2rqNUPgkBgbhcRabUQ5C9g
#
# [278 rows x 6 columns]

# %% [markdown]
# Get test data from : https://github.com/mdeff/fma . Use the raw_artists file found in fma_metadata.zip

# %%
path_to_artists_csv = os.path.expanduser("~") + "/Downloads/fma_metadata/raw_artists.csv"
artists_df = pd.read_csv(path_to_artists_csv, index_col=0, usecols=['artist_name', 'artist_id'])
artists_df = artists_df.rename(columns={"artist_name": "artistName"})
artists_df = artists_df.sample(800)

# %%
add_genres_to_artists(artists_df)
artists_df
# Out:
#                   artistName  \
# artist_id
# 385                    Adept
# 7198                  Moolen
# 20589                    K3N
# 20509           Ford Hanford
# 20388              LEE OTHER
# ...                      ...
# 4377            Jesus du Dos
# 12527          Nebe-Quartett
# 10313              Hal McGee
# 9345                   angil
# 16957      Secrets Of The 45
#
#                                                       genres  \
# artist_id
# 385        [melodic metalcore, metalcore, screamo, swedis...
# 7198       [glam metal, hard rock, metal, rock, sleaze rock]
# 20589                                     [chicago rap, rap]
# 20509                                                     []
# 20388                                                     []
# ...                                                      ...
# 4377                                                      []
# 12527                                           [vaudeville]
# 10313                                                     []
# 9345                        [belgian pop, variete francaise]
# 16957                                                     []
#
#                          artistId
# artist_id
# 385        1TsgX8DlUvpk9mrUqxmOZu
# 7198       0cc6vw3VN8YlIcvr1v7tBL
# 20589      5K4W6rqBFWDnAN6FQUkS6x
# 20509
# 20388      23woqvFe3BOc8ifi2z8IHF
# ...                           ...
# 4377
# 12527      06sCDDkD5MMazN3juL8XHq
# 10313      1pn43stRVM96FRKglA7ltP
# 9345       3QVolfxko2UyCOtexhVTli
# 16957
#
# [800 rows x 3 columns]

# %%
# Filter out any artist that doesn't have genres or fewer than 2 genres
filtered_artists_df = artists_df[artists_df["genres"].apply(len).gt(0)]
filtered_artists_df
# Out:
#                    artistName  \
# artist_id
# 385                     Adept
# 7198                   Moolen
# 20589                     K3N
# 16913                    Agan
# 13498                     Zea
# ...                       ...
# 6291       Dark Time Sunshine
# 1165                 Quintron
# 16536                     COW
# 12527           Nebe-Quartett
# 9345                    angil
#
#                                                       genres  \
# artist_id
# 385        [melodic metalcore, metalcore, screamo, swedis...
# 7198       [glam metal, hard rock, metal, rock, sleaze rock]
# 20589                                     [chicago rap, rap]
# 16913                                        [electro house]
# 13498                       [avant-garde metal, swiss metal]
# ...                                                      ...
# 6291       [abstract hip hop, seattle hip hop, undergroun...
# 1165                                     [garage punk blues]
# 16536      [alternative country, classic canadian rock, c...
# 12527                                           [vaudeville]
# 9345                        [belgian pop, variete francaise]
#
#                          artistId
# artist_id
# 385        1TsgX8DlUvpk9mrUqxmOZu
# 7198       0cc6vw3VN8YlIcvr1v7tBL
# 20589      5K4W6rqBFWDnAN6FQUkS6x
# 16913      7vk5e3vY1uw9plTHJAMwjN
# 13498      6yCjbLFZ9qAnWfsy9ujm5Y
# ...                           ...
# 6291       5cfC9eCiLaXJJFqJRnj0gW
# 1165       7oYKm5OvA9Z2TZZWCoqMz1
# 16536      3CYSRCHfilgR8DSbkCMp5j
# 12527      06sCDDkD5MMazN3juL8XHq
# 9345       3QVolfxko2UyCOtexhVTli
#
# [237 rows x 3 columns]

# %%
combined = pd.concat([my_music, filtered_artists_df], axis=0)
combined
# Out:
#                 endTime          artistName                       trackName  \
# 1200   2019-11-12 22:34            Converge                     Hell to Pay
# 20105  2020-09-29 17:34               IDLES         Kill Them With Kindness
# 9065   2020-04-30 18:35             RXYZYXR    Polar Knights (Instrumental)
# 11555  2020-07-01 16:31  The Human Abstract                    Digital Veil
# 10719  2020-06-11 15:19            Kid Cudi  Flight At First Sight/Advanced
# ...                 ...                 ...                             ...
# 6291                NaN  Dark Time Sunshine                             NaN
# 1165                NaN            Quintron                             NaN
# 16536               NaN                 COW                             NaN
# 12527               NaN       Nebe-Quartett                             NaN
# 9345                NaN               angil                             NaN
#
#        msPlayed                                             genres  \
# 1200   271773.0  [boston hardcore, chaotic hardcore, mathcore, ...
# 20105  229579.0  [bristol indie, modern alternative rock, moder...
# 9065   294028.0     [djent, instrumental progressive metal, thall]
# 11555  210360.0  [deathcore, djent, melodic metalcore, progress...
# 10719  116948.0                       [hip hop, ohio hip hop, rap]
# ...         ...                                                ...
# 6291        NaN  [abstract hip hop, seattle hip hop, undergroun...
# 1165        NaN                                [garage punk blues]
# 16536       NaN  [alternative country, classic canadian rock, c...
# 12527       NaN                                       [vaudeville]
# 9345        NaN                   [belgian pop, variete francaise]
#
#                      artistId
# 1200   7kHzfxMLtVHHb523s43rY1
# 20105  75mafsNqNE1WSEVxIKuY5C
# 9065   4KScLR4NpZbGiXzj9FSA85
# 11555  2SDGIFzEh9xmE5zDKcMRkj
# 10719  0fA0VVWsXO9YnASrzqfmYu
# ...                       ...
# 6291   5cfC9eCiLaXJJFqJRnj0gW
# 1165   7oYKm5OvA9Z2TZZWCoqMz1
# 16536  3CYSRCHfilgR8DSbkCMp5j
# 12527  06sCDDkD5MMazN3juL8XHq
# 9345   3QVolfxko2UyCOtexhVTli
#
# [515 rows x 6 columns]

# %%
combined['Key_words'] = ""
combined['Key_words'] = combined['Key_words'].astype(object)

for index, row in combined.iterrows():
    genres = ' '.join(row['genres'])
    
    # instantiating Rake, by default it uses english stopwords from NLTK
    # and discards all puntuation characters as well
    r = Rake()

    # extracting the words by passing the text
    r.extract_keywords_from_text(genres)

    # getting the dictionary whith key words as keys and their scores as values
    key_words_dict_scores = r.get_word_degrees()
    
    # assigning the key words to the new column for the corresponding artist
    combined.at[index, 'Key_words'] = ' '.join(list(key_words_dict_scores.keys()))

combined.set_index('artistName', inplace = True)
combined
# Out:
#                              endTime                       trackName  \
# artistName
# Converge            2019-11-12 22:34                     Hell to Pay
# IDLES               2020-09-29 17:34         Kill Them With Kindness
# RXYZYXR             2020-04-30 18:35    Polar Knights (Instrumental)
# The Human Abstract  2020-07-01 16:31                    Digital Veil
# Kid Cudi            2020-06-11 15:19  Flight At First Sight/Advanced
# ...                              ...                             ...
# Dark Time Sunshine               NaN                             NaN
# Quintron                         NaN                             NaN
# COW                              NaN                             NaN
# Nebe-Quartett                    NaN                             NaN
# angil                            NaN                             NaN
#
#                     msPlayed  \
# artistName
# Converge            271773.0
# IDLES               229579.0
# RXYZYXR             294028.0
# The Human Abstract  210360.0
# Kid Cudi            116948.0
# ...                      ...
# Dark Time Sunshine       NaN
# Quintron                 NaN
# COW                      NaN
# Nebe-Quartett            NaN
# angil                    NaN
#
#                                                                genres  \
# artistName
# Converge            [boston hardcore, chaotic hardcore, mathcore, ...
# IDLES               [bristol indie, modern alternative rock, moder...
# RXYZYXR                [djent, instrumental progressive metal, thall]
# The Human Abstract  [deathcore, djent, melodic metalcore, progress...
# Kid Cudi                                 [hip hop, ohio hip hop, rap]
# ...                                                               ...
# Dark Time Sunshine  [abstract hip hop, seattle hip hop, undergroun...
# Quintron                                          [garage punk blues]
# COW                 [alternative country, classic canadian rock, c...
# Nebe-Quartett                                            [vaudeville]
# angil                                [belgian pop, variete francaise]
#
#                                   artistId  \
# artistName
# Converge            7kHzfxMLtVHHb523s43rY1
# IDLES               75mafsNqNE1WSEVxIKuY5C
# RXYZYXR             4KScLR4NpZbGiXzj9FSA85
# The Human Abstract  2SDGIFzEh9xmE5zDKcMRkj
# Kid Cudi            0fA0VVWsXO9YnASrzqfmYu
# ...                                    ...
# Dark Time Sunshine  5cfC9eCiLaXJJFqJRnj0gW
# Quintron            7oYKm5OvA9Z2TZZWCoqMz1
# COW                 3CYSRCHfilgR8DSbkCMp5j
# Nebe-Quartett       06sCDDkD5MMazN3juL8XHq
# angil               3QVolfxko2UyCOtexhVTli
#
#                                                             Key_words
# artistName
# Converge            hardcore screamo doom metal post boston chaoti...
# IDLES                           bristol indie modern alternative rock
# RXYZYXR                    djent instrumental progressive metal thall
# The Human Abstract      deathcore djent melodic metalcore progressive
# Kid Cudi                                             hip hop ohio rap
# ...                                                               ...
# Dark Time Sunshine           abstract hip hop seattle underground rap
# Quintron                                            garage punk blues
# COW                 alternative country classic canadian rock folk...
# Nebe-Quartett                                              vaudeville
# angil                                   belgian pop variete francaise
#
# [515 rows x 6 columns]

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(combined['Key_words'])

# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
def formulate_bottom_two_artists(df, score_series, my_music_artists):
    recommended_artists = []
    i = 0
    list_df = list(df.index)
    while len(recommended_artists) < 2:
        artist_idx = score_series.index[i]
        artist = list_df[artist_idx]
        artistId = list(df.loc[[artist]]["artistId"])[0]
        
        # Make sure to not recommend artists that are part of my_music
        if artist not in my_music_artists:
            recommended_artists.append({"name": artist, "spotifyId": artistId})
        i += 1
    return recommended_artists

# Given artist name, and dataframes, return the bottom two artists to recommend
def recommend_artists(df, artist_name, cosine_sim, my_music_artists):
    
    # creating a Series for the movie titles so they are associated to an ordered numerical
    # list I will use in the function to match the indexes
    indices = pd.Series(df.index)
    
    # initializing the empty list of recommended movies
    recommended_artists = []
    
    # gettin the index of the artist_name that matches the one provided as input
    idx = indices[indices == artist_name].index[0]

    # creating a Series with the similarity scores in ascending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = True)

    return formulate_bottom_two_artists(df, score_series, my_music_artists)
    

my_music_artists = list(my_music["artistName"])
recommend_artists(combined, 'JPEGMAFIA', cosine_sim, my_music_artists)
# Out:
# [{'name': 'Samara Lubelski', 'spotifyId': '7m0vo8YcqFNXFOoKycpOES'},
#  {'name': 'Jawbone', 'spotifyId': '0p2DpCY7eufSqZpW1mAZij'}]

# %%
recommendation_artists = set()
recommendations = list()
sample = my_music.sample(20)
for index, row in sample.iterrows():
    recommended = recommend_artists(combined, row["artistName"], cosine_sim, my_music_artists)
    for item in recommended:
        if item["name"] not in recommendation_artists:
            recommendations.append(item)
            recommendation_artists.add(item["name"])
recommendations
# Out:
# [{'name': 'Jawbone', 'spotifyId': '0p2DpCY7eufSqZpW1mAZij'},
#  {'name': 'And.', 'spotifyId': '3jK9MiCrA42lLAdMGUZpwa'},
#  {'name': 'Koban', 'spotifyId': '1q7T9rFQ2a2ukA1PU51fo3'},
#  {'name': 'GV', 'spotifyId': '14jz3w0nEENe6ewnpSqRvf'},
#  {'name': 'angil', 'spotifyId': '3QVolfxko2UyCOtexhVTli'},
#  {'name': 'K3N', 'spotifyId': '5K4W6rqBFWDnAN6FQUkS6x'},
#  {'name': 'Failure', 'spotifyId': '3grvcGPaLhfrD5CYsecr4j'},
#  {'name': 'Chamber Music Society of Lincoln Center',
#   'spotifyId': '7D5qegbCcQwEnPuRVOlB62'},
#  {'name': 'Organoid', 'spotifyId': '0FjF4Knsp7DEVujXASJBdO'},
#  {'name': 'ZMG', 'spotifyId': '6tuPdaFPIytg3l2f51L7Hw'},
#  {'name': 'blithe field', 'spotifyId': '4effiSDHnV1sU1FaLSWIRS'},
#  {'name': 'The Blend', 'spotifyId': '6SieHXbnzLxi9SVCO1Iv8P'},
#  {'name': 'Cursillistas', 'spotifyId': '24HffIPc0fRXaYOzQhIMuc'},
#  {'name': 'Wavves', 'spotifyId': '6bUJpbekaIlq2fT5FMV2mQ'},
#  {'name': 'Shogun', 'spotifyId': '6diiyZ15AVZoSxzAyjIYJT'},
#  {'name': '회사AUTO', 'spotifyId': '3rWJqI55ysYgFzbR5ZhX5s'},
#  {'name': 'Ayla Nereo', 'spotifyId': '4gJMOPjz1OUnD6TysFPUr1'},
#  {'name': 'Samara Lubelski', 'spotifyId': '7m0vo8YcqFNXFOoKycpOES'},
#  {'name': 'Discoballs', 'spotifyId': '2FNRhZFRUpECaVzy1iqp90'},
#  {'name': 'Fern Knight', 'spotifyId': '2yrDSL7dv41gPRj2luFACv'},
#  {'name': 'Imperial Tiger Orchestra', 'spotifyId': '1WccCkOM6XoDxycI6yxq2A'},
#  {'name': 'Absolute Monarchs', 'spotifyId': '5VdsfTWw9hbZ5UakmVPb5P'},
#  {'name': 'Daniel Bachman', 'spotifyId': '3beAmqA2s5xwxDAIFJwDG9'},
#  {'name': 'Kib Lib', 'spotifyId': '0A5hWmrfSIIExWIb1bsWlo'},
#  {'name': 'Nebe-Quartett', 'spotifyId': '06sCDDkD5MMazN3juL8XHq'}]

# %%
def get_spotify_top_track(artist_id):
    url = 'https://api.spotify.com/v1/artists/{}/top-tracks'.format(artist_id)
    params = {'market': 'US'}
    r = requests.get(url, 
                     headers={"Authorization": "Bearer {}".format(spotify_auth)},
                     params=params)
    if r.status_code == 401:
        raise Exception(r.json())
    return r.json()

# %% [markdown]
# Find the top track of each recommended artist and save the spotify track id

# %%
list_of_top_track_ids = []
for item in recommendations:
    list_of_top_track_ids.append(get_spotify_top_track(item["spotifyId"])["tracks"][0]["uri"])
    
list_of_top_track_ids
# Out:
# ['spotify:track:34UOSXZVpd5oRnCeUHvAPN',
#  'spotify:track:2IFFKj9orAsQOOS0JRhHAW',
#  'spotify:track:70pkwEEG7nDTXBFqoGQkH0',
#  'spotify:track:35q7X4tARttH2r0ByoJOJt',
#  'spotify:track:3F1P0QzdXtBz0MXy7KIO5w',
#  'spotify:track:4fzsfWzRhPawzqhX8Qt9F3',
#  'spotify:track:50iBJRkGjjht3RiwD0VqLA',
#  'spotify:track:0hCbtOo9aFH3RDybCUi07Z',
#  'spotify:track:7sfNMu2SJCHE7Tf1WHz9cg',
#  'spotify:track:5lN3gM5Q6rcHzkY6TFAslJ',
#  'spotify:track:1ifq1Ig1498noPWG2IMOVe',
#  'spotify:track:0IY0VdkmEf4oQQPS4GmPGN',
#  'spotify:track:6KxZIG1dny5wX701ZhMZEh',
#  'spotify:track:6sChW7Z0IwSvvBR6m4dMws',
#  'spotify:track:6lOnmMUBxANDriVh2kQqkG',
#  'spotify:track:68Lzr6nZ7V2JQKaFH2wCuS',
#  'spotify:track:6uYM1xsg69mzynbikvv5Rq',
#  'spotify:track:1PRBkBQmQZAlGMJ6KvxG4A',
#  'spotify:track:7tHo8zOzTRa3tAPqdNPmH8',
#  'spotify:track:1hE4ybk6fEKqYRDeLpwpLt',
#  'spotify:track:4U8xPuXwq9MpBqgrprIEg5',
#  'spotify:track:1vcaDCPU3B9UZFxAF9NeVN',
#  'spotify:track:1LfGP4l3u94cu57cR4khzq',
#  'spotify:track:1x6xY7mgpXFRnY8mPgXbx9',
#  'spotify:track:59GXlHkbJk1sC9LCCBT7cA']

# %%
def create_spotify_playlist():
    url = 'https://api.spotify.com/v1/me'
    r = requests.get(url, 
                     headers={"Authorization": "Bearer {}".format(spotify_auth)},
                     params=params)
    if r.status_code == 401:
        raise Exception(r.json())
    user_id = r.json()["id"]
    
    url = "https://api.spotify.com/v1/users/{}/playlists".format(user_id)
    body = {"name": "Recommendation Engine Created",
            "description": "Some music I'm sure I won't enjoy",
            "public": "true"}
    r = requests.post(url,
                      headers={"Authorization": "Bearer {}".format(spotify_auth)},
                      json=body)
    
    return r.json()

# %%
create_spotify_playlist()

# %%
playlist_id = "4TSQ7pxlk2couFmdV3VJME"

# %%
def add_track_to_playlist(playlist_id, tracklist):
    body = json.dumps({"uris": tracklist})       
    
    url = "https://api.spotify.com/v1/playlists/{}/tracks".format(playlist_id)

    r = requests.post(url,
                      headers={"Authorization": "Bearer {}".format(spotify_auth)},
                      data=body)
    
    return r.json()

# %%
add_track_to_playlist(playlist_id, list_of_top_track_ids)
# Out:
# {'snapshot_id': 'MywzNmFhZDhmNjAxNjQ0Mzg0ZTU3NmZjYjVjOTJiMWUwZjEzYzU5Yzkz'}
